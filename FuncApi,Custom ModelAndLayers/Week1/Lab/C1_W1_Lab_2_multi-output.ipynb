# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

print(tf.__version__)
# Out:
# 2.1.0

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Get the data from UCI dataset
URL = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00242/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URL)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()
print(train_stats)
# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)
# Out:
#                X1          X2          X3          X4          X5          X6  \
# count  614.000000  614.000000  614.000000  614.000000  614.000000  614.000000
# mean     0.764756  671.236156  319.218241  176.008958    5.267101    3.504886
# std      0.106418   88.358372   43.803157   45.354276    1.751343    1.102781
# min      0.620000  514.500000  245.000000  110.250000    3.500000    2.000000
# 25%      0.667500  594.125000  294.000000  122.500000    3.500000    3.000000
# 50%      0.760000  661.500000  318.500000  147.000000    7.000000    3.000000
# 75%      0.850000  753.375000  343.000000  220.500000    7.000000    4.000000
# max      0.980000  808.500000  416.500000  220.500000    7.000000    5.000000
#
#                X7          X8          Y1          Y2
# count  614.000000  614.000000  614.000000  614.000000
# mean     0.234283    2.822476   22.439814   24.777296
# std      0.132985    1.545213   10.158602    9.640083
# min      0.000000    0.000000    6.010000   10.900000
# 25%      0.100000    2.000000   13.000000   15.632500
# 50%      0.250000    3.000000   18.950000   22.510000
# 75%      0.400000    4.000000   32.112500   33.362500
# max      0.400000    5.000000   43.100000   48.030000

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train.columns),))
first_dense = Dense(units=128,activation=tf.nn.relu)(input_layer)
second_dense = Dense(units=128,activation=tf.nn.relu)(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 128)          1152        input_3[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 128)          16512       dense_5[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 64)           8256        dense_6[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_6[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_7[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': tf.keras.losses.MeanSquaredError(), 'y2_output': tf.keras.losses.MeanSquaredError()},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 842us/sample - loss: 242.6584 - y1_output_loss: 113.3042 - y2_output_loss: 127.9704 - y1_output_root_mean_squared_error: 10.6773 - y2_output_root_mean_squared_error: 11.3426 - val_loss: 204.0689 - val_y1_output_loss: 46.1086 - val_y2_output_loss: 150.9568 - val_y1_output_root_mean_squared_error: 6.9002 - val_y2_output_root_mean_squared_error: 12.5082
# Epoch 2/500
# 614/614 [==============================] - 0s 135us/sample - loss: 41.3236 - y1_output_loss: 14.5905 - y2_output_loss: 26.4192 - y1_output_root_mean_squared_error: 3.8367 - y2_output_root_mean_squared_error: 5.1578 - val_loss: 29.2119 - val_y1_output_loss: 9.3449 - val_y2_output_loss: 18.9933 - val_y1_output_root_mean_squared_error: 3.0919 - val_y2_output_root_mean_squared_error: 4.4330
# Epoch 3/500
# 614/614 [==============================] - 0s 145us/sample - loss: 26.8232 - y1_output_loss: 10.3872 - y2_output_loss: 16.2398 - y1_output_root_mean_squared_error: 3.2332 - y2_output_root_mean_squared_error: 4.0459 - val_loss: 17.6261 - val_y1_output_loss: 8.5291 - val_y2_output_loss: 8.5867 - val_y1_output_root_mean_squared_error: 2.9616 - val_y2_output_root_mean_squared_error: 2.9758
# Epoch 4/500
# 614/614 [==============================] - 0s 133us/sample - loss: 30.4064 - y1_output_loss: 10.5857 - y2_output_loss: 19.6374 - y1_output_root_mean_squared_error: 3.2667 - y2_output_root_mean_squared_error: 4.4424 - val_loss: 17.7593 - val_y1_output_loss: 8.6284 - val_y2_output_loss: 8.5993 - val_y1_output_root_mean_squared_error: 2.9787 - val_y2_output_root_mean_squared_error: 2.9810
# Epoch 5/500
# 614/614 [==============================] - 0s 131us/sample - loss: 22.9823 - y1_output_loss: 8.6343 - y2_output_loss: 14.1449 - y1_output_root_mean_squared_error: 2.9517 - y2_output_root_mean_squared_error: 3.7775 - val_loss: 20.6902 - val_y1_output_loss: 8.1329 - val_y2_output_loss: 11.8722 - val_y1_output_root_mean_squared_error: 2.8964 - val_y2_output_root_mean_squared_error: 3.5073
# Epoch 6/500
# 614/614 [==============================] - 0s 137us/sample - loss: 23.5282 - y1_output_loss: 8.8811 - y2_output_loss: 14.7758 - y1_output_root_mean_squared_error: 2.9772 - y2_output_root_mean_squared_error: 3.8294 - val_loss: 34.7400 - val_y1_output_loss: 9.3481 - val_y2_output_loss: 24.2319 - val_y1_output_root_mean_squared_error: 3.1083 - val_y2_output_root_mean_squared_error: 5.0078
# Epoch 7/500
# 614/614 [==============================] - 0s 125us/sample - loss: 25.5351 - y1_output_loss: 9.2518 - y2_output_loss: 16.0676 - y1_output_root_mean_squared_error: 3.0541 - y2_output_root_mean_squared_error: 4.0259 - val_loss: 18.5832 - val_y1_output_loss: 8.8106 - val_y2_output_loss: 9.1311 - val_y1_output_root_mean_squared_error: 3.0181 - val_y2_output_root_mean_squared_error: 3.0781
# Epoch 8/500
# 614/614 [==============================] - 0s 124us/sample - loss: 22.1780 - y1_output_loss: 8.5995 - y2_output_loss: 13.7052 - y1_output_root_mean_squared_error: 2.9197 - y2_output_root_mean_squared_error: 3.6950 - val_loss: 46.6876 - val_y1_output_loss: 18.5702 - val_y2_output_loss: 26.4792 - val_y1_output_root_mean_squared_error: 4.3873 - val_y2_output_root_mean_squared_error: 5.2383
# Epoch 9/500
# 614/614 [==============================] - 0s 127us/sample - loss: 24.2896 - y1_output_loss: 9.1373 - y2_output_loss: 15.0635 - y1_output_root_mean_squared_error: 3.0169 - y2_output_root_mean_squared_error: 3.8971 - val_loss: 16.5562 - val_y1_output_loss: 8.2503 - val_y2_output_loss: 7.7546 - val_y1_output_root_mean_squared_error: 2.9195 - val_y2_output_root_mean_squared_error: 2.8342
# Epoch 10/500
# 614/614 [==============================] - 0s 129us/sample - loss: 22.1222 - y1_output_loss: 7.9500 - y2_output_loss: 14.0136 - y1_output_root_mean_squared_error: 2.8262 - y2_output_root_mean_squared_error: 3.7596 - val_loss: 16.7747 - val_y1_output_loss: 7.5316 - val_y2_output_loss: 8.6817 - val_y1_output_root_mean_squared_error: 2.7880 - val_y2_output_root_mean_squared_error: 3.0002
# Epoch 11/500
# 614/614 [==============================] - 0s 133us/sample - loss: 20.7558 - y1_output_loss: 7.7714 - y2_output_loss: 12.9376 - y1_output_root_mean_squared_error: 2.7867 - y2_output_root_mean_squared_error: 3.6041 - val_loss: 18.7882 - val_y1_output_loss: 8.0022 - val_y2_output_loss: 10.1602 - val_y1_output_root_mean_squared_error: 2.8755 - val_y2_output_root_mean_squared_error: 3.2434
# Epoch 12/500
# 614/614 [==============================] - 0s 130us/sample - loss: 19.2962 - y1_output_loss: 7.1994 - y2_output_loss: 12.1140 - y1_output_root_mean_squared_error: 2.6880 - y2_output_root_mean_squared_error: 3.4743 - val_loss: 38.5461 - val_y1_output_loss: 10.2521 - val_y2_output_loss: 26.9805 - val_y1_output_root_mean_squared_error: 3.2543 - val_y2_output_root_mean_squared_error: 5.2873
# Epoch 13/500
# 614/614 [==============================] - 0s 133us/sample - loss: 18.6406 - y1_output_loss: 7.2863 - y2_output_loss: 11.3728 - y1_output_root_mean_squared_error: 2.6800 - y2_output_root_mean_squared_error: 3.3850 - val_loss: 18.0247 - val_y1_output_loss: 7.8788 - val_y2_output_loss: 9.6068 - val_y1_output_root_mean_squared_error: 2.8509 - val_y2_output_root_mean_squared_error: 3.1460
# Epoch 14/500
# 614/614 [==============================] - 0s 126us/sample - loss: 19.1854 - y1_output_loss: 6.9595 - y2_output_loss: 12.2357 - y1_output_root_mean_squared_error: 2.6402 - y2_output_root_mean_squared_error: 3.4949 - val_loss: 15.6102 - val_y1_output_loss: 7.2284 - val_y2_output_loss: 7.8645 - val_y1_output_root_mean_squared_error: 2.7326 - val_y2_output_root_mean_squared_error: 2.8536
# Epoch 15/500
# 614/614 [==============================] - 0s 131us/sample - loss: 20.1668 - y1_output_loss: 6.8798 - y2_output_loss: 13.1590 - y1_output_root_mean_squared_error: 2.6317 - y2_output_root_mean_squared_error: 3.6388 - val_loss: 20.6616 - val_y1_output_loss: 6.9180 - val_y2_output_loss: 13.0693 - val_y1_output_root_mean_squared_error: 2.6746 - val_y2_output_root_mean_squared_error: 3.6753
# Epoch 16/500
# 614/614 [==============================] - 0s 136us/sample - loss: 15.8574 - y1_output_loss: 6.2165 - y2_output_loss: 9.5043 - y1_output_root_mean_squared_error: 2.5043 - y2_output_root_mean_squared_error: 3.0961 - val_loss: 13.7077 - val_y1_output_loss: 6.3226 - val_y2_output_loss: 6.9199 - val_y1_output_root_mean_squared_error: 2.5563 - val_y2_output_root_mean_squared_error: 2.6782
# Epoch 17/500
# 614/614 [==============================] - 0s 133us/sample - loss: 16.5672 - y1_output_loss: 6.0158 - y2_output_loss: 10.4847 - y1_output_root_mean_squared_error: 2.4586 - y2_output_root_mean_squared_error: 3.2439 - val_loss: 27.0051 - val_y1_output_loss: 7.9597 - val_y2_output_loss: 18.1739 - val_y1_output_root_mean_squared_error: 2.8677 - val_y2_output_root_mean_squared_error: 4.3338
# Epoch 18/500
# 614/614 [==============================] - 0s 127us/sample - loss: 16.1414 - y1_output_loss: 5.8764 - y2_output_loss: 10.3932 - y1_output_root_mean_squared_error: 2.4186 - y2_output_root_mean_squared_error: 3.2081 - val_loss: 35.4677 - val_y1_output_loss: 9.9726 - val_y2_output_loss: 24.2765 - val_y1_output_root_mean_squared_error: 3.2130 - val_y2_output_root_mean_squared_error: 5.0144
# Epoch 19/500
# 614/614 [==============================] - 0s 129us/sample - loss: 15.3280 - y1_output_loss: 5.3495 - y2_output_loss: 9.8694 - y1_output_root_mean_squared_error: 2.3232 - y2_output_root_mean_squared_error: 3.1513 - val_loss: 14.5364 - val_y1_output_loss: 6.5784 - val_y2_output_loss: 7.4556 - val_y1_output_root_mean_squared_error: 2.6091 - val_y2_output_root_mean_squared_error: 2.7801
# Epoch 20/500
# 614/614 [==============================] - 0s 131us/sample - loss: 14.2057 - y1_output_loss: 5.4236 - y2_output_loss: 8.6846 - y1_output_root_mean_squared_error: 2.3359 - y2_output_root_mean_squared_error: 2.9579 - val_loss: 12.4401 - val_y1_output_loss: 5.5776 - val_y2_output_loss: 6.4323 - val_y1_output_root_mean_squared_error: 2.4016 - val_y2_output_root_mean_squared_error: 2.5831
# Epoch 21/500
# 614/614 [==============================] - 0s 126us/sample - loss: 13.1502 - y1_output_loss: 5.0468 - y2_output_loss: 8.0615 - y1_output_root_mean_squared_error: 2.2456 - y2_output_root_mean_squared_error: 2.8473 - val_loss: 11.5701 - val_y1_output_loss: 5.2430 - val_y2_output_loss: 5.9566 - val_y1_output_root_mean_squared_error: 2.3271 - val_y2_output_root_mean_squared_error: 2.4809
# Epoch 22/500
# 614/614 [==============================] - 0s 128us/sample - loss: 13.9509 - y1_output_loss: 4.9176 - y2_output_loss: 9.0813 - y1_output_root_mean_squared_error: 2.2040 - y2_output_root_mean_squared_error: 3.0155 - val_loss: 11.7205 - val_y1_output_loss: 6.2655 - val_y2_output_loss: 5.0611 - val_y1_output_root_mean_squared_error: 2.5456 - val_y2_output_root_mean_squared_error: 2.2892
# Epoch 23/500
# 614/614 [==============================] - 0s 130us/sample - loss: 14.0708 - y1_output_loss: 4.8535 - y2_output_loss: 9.2631 - y1_output_root_mean_squared_error: 2.1965 - y2_output_root_mean_squared_error: 3.0407 - val_loss: 10.9102 - val_y1_output_loss: 5.2828 - val_y2_output_loss: 5.2593 - val_y1_output_root_mean_squared_error: 2.3364 - val_y2_output_root_mean_squared_error: 2.3349
# Epoch 24/500
# 614/614 [==============================] - 0s 126us/sample - loss: 13.5715 - y1_output_loss: 4.8242 - y2_output_loss: 8.6610 - y1_output_root_mean_squared_error: 2.2040 - y2_output_root_mean_squared_error: 2.9519 - val_loss: 10.6369 - val_y1_output_loss: 5.1391 - val_y2_output_loss: 5.1408 - val_y1_output_root_mean_squared_error: 2.3047 - val_y2_output_root_mean_squared_error: 2.3076
# Epoch 25/500
# 614/614 [==============================] - 0s 126us/sample - loss: 12.4719 - y1_output_loss: 4.4248 - y2_output_loss: 7.9857 - y1_output_root_mean_squared_error: 2.1077 - y2_output_root_mean_squared_error: 2.8336 - val_loss: 11.1730 - val_y1_output_loss: 5.0775 - val_y2_output_loss: 5.7122 - val_y1_output_root_mean_squared_error: 2.2914 - val_y2_output_root_mean_squared_error: 2.4336
# Epoch 26/500
# 614/614 [==============================] - 0s 130us/sample - loss: 11.7110 - y1_output_loss: 4.2113 - y2_output_loss: 7.5692 - y1_output_root_mean_squared_error: 2.0576 - y2_output_root_mean_squared_error: 2.7345 - val_loss: 28.0435 - val_y1_output_loss: 6.2173 - val_y2_output_loss: 20.8511 - val_y1_output_root_mean_squared_error: 2.5368 - val_y2_output_root_mean_squared_error: 4.6485
# Epoch 27/500
# 614/614 [==============================] - 0s 125us/sample - loss: 13.4936 - y1_output_loss: 4.6009 - y2_output_loss: 8.8752 - y1_output_root_mean_squared_error: 2.1474 - y2_output_root_mean_squared_error: 2.9803 - val_loss: 9.9920 - val_y1_output_loss: 4.8869 - val_y2_output_loss: 4.7770 - val_y1_output_root_mean_squared_error: 2.2475 - val_y2_output_root_mean_squared_error: 2.2228
# Epoch 28/500
# 614/614 [==============================] - 0s 124us/sample - loss: 10.2490 - y1_output_loss: 3.5967 - y2_output_loss: 6.6038 - y1_output_root_mean_squared_error: 1.8993 - y2_output_root_mean_squared_error: 2.5772 - val_loss: 8.6909 - val_y1_output_loss: 4.1732 - val_y2_output_loss: 4.2268 - val_y1_output_root_mean_squared_error: 2.0774 - val_y2_output_root_mean_squared_error: 2.0917
# Epoch 29/500
# 614/614 [==============================] - 0s 132us/sample - loss: 10.7697 - y1_output_loss: 3.7311 - y2_output_loss: 7.0415 - y1_output_root_mean_squared_error: 1.9236 - y2_output_root_mean_squared_error: 2.6588 - val_loss: 14.7696 - val_y1_output_loss: 5.9356 - val_y2_output_loss: 8.3434 - val_y1_output_root_mean_squared_error: 2.4778 - val_y2_output_root_mean_squared_error: 2.9377
# Epoch 30/500
# 614/614 [==============================] - 0s 136us/sample - loss: 11.0575 - y1_output_loss: 3.5972 - y2_output_loss: 7.4322 - y1_output_root_mean_squared_error: 1.8997 - y2_output_root_mean_squared_error: 2.7292 - val_loss: 10.1862 - val_y1_output_loss: 5.0430 - val_y2_output_loss: 4.8566 - val_y1_output_root_mean_squared_error: 2.2787 - val_y2_output_root_mean_squared_error: 2.2346
# Epoch 31/500
# 614/614 [==============================] - 0s 128us/sample - loss: 11.8464 - y1_output_loss: 3.9491 - y2_output_loss: 7.8249 - y1_output_root_mean_squared_error: 1.9924 - y2_output_root_mean_squared_error: 2.8066 - val_loss: 8.6449 - val_y1_output_loss: 3.7873 - val_y2_output_loss: 4.5898 - val_y1_output_root_mean_squared_error: 1.9750 - val_y2_output_root_mean_squared_error: 2.1781
# Epoch 32/500
# 614/614 [==============================] - 0s 139us/sample - loss: 9.8433 - y1_output_loss: 3.5553 - y2_output_loss: 6.4019 - y1_output_root_mean_squared_error: 1.8653 - y2_output_root_mean_squared_error: 2.5227 - val_loss: 11.9803 - val_y1_output_loss: 6.3262 - val_y2_output_loss: 5.2513 - val_y1_output_root_mean_squared_error: 2.5584 - val_y2_output_root_mean_squared_error: 2.3312
# Epoch 33/500
# 614/614 [==============================] - 0s 138us/sample - loss: 9.8298 - y1_output_loss: 3.2475 - y2_output_loss: 6.5416 - y1_output_root_mean_squared_error: 1.8094 - y2_output_root_mean_squared_error: 2.5605 - val_loss: 15.0152 - val_y1_output_loss: 4.2307 - val_y2_output_loss: 10.2704 - val_y1_output_root_mean_squared_error: 2.0910 - val_y2_output_root_mean_squared_error: 3.2623
# Epoch 34/500
# 614/614 [==============================] - 0s 137us/sample - loss: 8.3713 - y1_output_loss: 2.7044 - y2_output_loss: 5.8168 - y1_output_root_mean_squared_error: 1.6492 - y2_output_root_mean_squared_error: 2.3772 - val_loss: 21.3084 - val_y1_output_loss: 5.0464 - val_y2_output_loss: 15.5671 - val_y1_output_root_mean_squared_error: 2.2854 - val_y2_output_root_mean_squared_error: 4.0106
# Epoch 35/500
# 614/614 [==============================] - 0s 142us/sample - loss: 8.8360 - y1_output_loss: 2.8729 - y2_output_loss: 5.9150 - y1_output_root_mean_squared_error: 1.6994 - y2_output_root_mean_squared_error: 2.4389 - val_loss: 7.9744 - val_y1_output_loss: 3.0653 - val_y2_output_loss: 4.6740 - val_y1_output_root_mean_squared_error: 1.7776 - val_y2_output_root_mean_squared_error: 2.1942
# Epoch 36/500
# 614/614 [==============================] - 0s 137us/sample - loss: 7.9184 - y1_output_loss: 2.7411 - y2_output_loss: 5.1380 - y1_output_root_mean_squared_error: 1.6602 - y2_output_root_mean_squared_error: 2.2721 - val_loss: 10.1581 - val_y1_output_loss: 3.3387 - val_y2_output_loss: 6.4724 - val_y1_output_root_mean_squared_error: 1.8584 - val_y2_output_root_mean_squared_error: 2.5893
# Epoch 37/500
# 614/614 [==============================] - 0s 137us/sample - loss: 11.0820 - y1_output_loss: 3.5524 - y2_output_loss: 7.5220 - y1_output_root_mean_squared_error: 1.8749 - y2_output_root_mean_squared_error: 2.7508 - val_loss: 9.0445 - val_y1_output_loss: 4.3175 - val_y2_output_loss: 4.4516 - val_y1_output_root_mean_squared_error: 2.1108 - val_y2_output_root_mean_squared_error: 2.1422
# Epoch 38/500
# 614/614 [==============================] - 0s 137us/sample - loss: 9.4479 - y1_output_loss: 3.3582 - y2_output_loss: 6.0131 - y1_output_root_mean_squared_error: 1.8402 - y2_output_root_mean_squared_error: 2.4620 - val_loss: 6.7842 - val_y1_output_loss: 3.1096 - val_y2_output_loss: 3.4712 - val_y1_output_root_mean_squared_error: 1.7901 - val_y2_output_root_mean_squared_error: 1.8920
# Epoch 39/500
# 614/614 [==============================] - 0s 126us/sample - loss: 9.1137 - y1_output_loss: 2.8740 - y2_output_loss: 6.3198 - y1_output_root_mean_squared_error: 1.6920 - y2_output_root_mean_squared_error: 2.5002 - val_loss: 10.0949 - val_y1_output_loss: 2.9711 - val_y2_output_loss: 6.8155 - val_y1_output_root_mean_squared_error: 1.7512 - val_y2_output_root_mean_squared_error: 2.6511
# Epoch 40/500
# 614/614 [==============================] - 0s 131us/sample - loss: 8.3985 - y1_output_loss: 2.7862 - y2_output_loss: 5.6500 - y1_output_root_mean_squared_error: 1.6738 - y2_output_root_mean_squared_error: 2.3657 - val_loss: 6.3275 - val_y1_output_loss: 2.4445 - val_y2_output_loss: 3.6737 - val_y1_output_root_mean_squared_error: 1.5892 - val_y2_output_root_mean_squared_error: 1.9498
# Epoch 41/500
# 614/614 [==============================] - 0s 127us/sample - loss: 7.3996 - y1_output_loss: 2.5601 - y2_output_loss: 4.8280 - y1_output_root_mean_squared_error: 1.6007 - y2_output_root_mean_squared_error: 2.1994 - val_loss: 12.3892 - val_y1_output_loss: 3.0703 - val_y2_output_loss: 8.9180 - val_y1_output_root_mean_squared_error: 1.7801 - val_y2_output_root_mean_squared_error: 3.0365
# Epoch 42/500
# 614/614 [==============================] - 0s 137us/sample - loss: 7.5415 - y1_output_loss: 2.4959 - y2_output_loss: 5.1341 - y1_output_root_mean_squared_error: 1.5776 - y2_output_root_mean_squared_error: 2.2478 - val_loss: 8.7672 - val_y1_output_loss: 3.3704 - val_y2_output_loss: 5.1137 - val_y1_output_root_mean_squared_error: 1.8663 - val_y2_output_root_mean_squared_error: 2.2987
# Epoch 43/500
# 614/614 [==============================] - 0s 128us/sample - loss: 8.7528 - y1_output_loss: 2.8903 - y2_output_loss: 5.8781 - y1_output_root_mean_squared_error: 1.7046 - y2_output_root_mean_squared_error: 2.4181 - val_loss: 7.4860 - val_y1_output_loss: 2.8301 - val_y2_output_loss: 4.3994 - val_y1_output_root_mean_squared_error: 1.7107 - val_y2_output_root_mean_squared_error: 2.1353
# Epoch 44/500
# 614/614 [==============================] - 0s 134us/sample - loss: 6.7750 - y1_output_loss: 2.1865 - y2_output_loss: 4.5854 - y1_output_root_mean_squared_error: 1.4654 - y2_output_root_mean_squared_error: 2.1512 - val_loss: 6.4427 - val_y1_output_loss: 2.6085 - val_y2_output_loss: 3.6284 - val_y1_output_root_mean_squared_error: 1.6416 - val_y2_output_root_mean_squared_error: 1.9359
# Epoch 45/500
# 614/614 [==============================] - 0s 138us/sample - loss: 6.2661 - y1_output_loss: 2.1441 - y2_output_loss: 4.2264 - y1_output_root_mean_squared_error: 1.4625 - y2_output_root_mean_squared_error: 2.0316 - val_loss: 6.3890 - val_y1_output_loss: 2.3718 - val_y2_output_loss: 3.8081 - val_y1_output_root_mean_squared_error: 1.5656 - val_y2_output_root_mean_squared_error: 1.9844
# Epoch 46/500
# 614/614 [==============================] - 0s 133us/sample - loss: 6.1262 - y1_output_loss: 2.0857 - y2_output_loss: 4.1125 - y1_output_root_mean_squared_error: 1.4225 - y2_output_root_mean_squared_error: 2.0255 - val_loss: 12.2772 - val_y1_output_loss: 4.9804 - val_y2_output_loss: 6.8615 - val_y1_output_root_mean_squared_error: 2.2718 - val_y2_output_root_mean_squared_error: 2.6676
# Epoch 47/500
# 614/614 [==============================] - 0s 135us/sample - loss: 6.9748 - y1_output_loss: 2.1463 - y2_output_loss: 4.8215 - y1_output_root_mean_squared_error: 1.4690 - y2_output_root_mean_squared_error: 2.1948 - val_loss: 12.5631 - val_y1_output_loss: 4.5439 - val_y2_output_loss: 7.5765 - val_y1_output_root_mean_squared_error: 2.1684 - val_y2_output_root_mean_squared_error: 2.8037
# Epoch 48/500
# 614/614 [==============================] - 0s 130us/sample - loss: 6.6395 - y1_output_loss: 2.1272 - y2_output_loss: 4.5250 - y1_output_root_mean_squared_error: 1.4403 - y2_output_root_mean_squared_error: 2.1366 - val_loss: 8.2546 - val_y1_output_loss: 3.8418 - val_y2_output_loss: 4.1435 - val_y1_output_root_mean_squared_error: 1.9941 - val_y2_output_root_mean_squared_error: 2.0684
# Epoch 49/500
# 614/614 [==============================] - 0s 126us/sample - loss: 7.1332 - y1_output_loss: 2.2475 - y2_output_loss: 4.9929 - y1_output_root_mean_squared_error: 1.5056 - y2_output_root_mean_squared_error: 2.2060 - val_loss: 31.2192 - val_y1_output_loss: 4.4231 - val_y2_output_loss: 25.7764 - val_y1_output_root_mean_squared_error: 2.1394 - val_y2_output_root_mean_squared_error: 5.1616
# Epoch 50/500
# 614/614 [==============================] - 0s 139us/sample - loss: 7.9037 - y1_output_loss: 2.2323 - y2_output_loss: 5.6381 - y1_output_root_mean_squared_error: 1.4962 - y2_output_root_mean_squared_error: 2.3801 - val_loss: 7.3189 - val_y1_output_loss: 2.5343 - val_y2_output_loss: 4.5486 - val_y1_output_root_mean_squared_error: 1.6190 - val_y2_output_root_mean_squared_error: 2.1674
# Epoch 51/500
# 614/614 [==============================] - 0s 135us/sample - loss: 6.9839 - y1_output_loss: 2.0486 - y2_output_loss: 4.9527 - y1_output_root_mean_squared_error: 1.4363 - y2_output_root_mean_squared_error: 2.2183 - val_loss: 21.7439 - val_y1_output_loss: 3.8212 - val_y2_output_loss: 17.2057 - val_y1_output_root_mean_squared_error: 1.9885 - val_y2_output_root_mean_squared_error: 4.2178
# Epoch 52/500
# 614/614 [==============================] - 0s 137us/sample - loss: 5.9525 - y1_output_loss: 1.7570 - y2_output_loss: 4.1391 - y1_output_root_mean_squared_error: 1.3319 - y2_output_root_mean_squared_error: 2.0442 - val_loss: 5.4305 - val_y1_output_loss: 2.0160 - val_y2_output_loss: 3.2477 - val_y1_output_root_mean_squared_error: 1.4432 - val_y2_output_root_mean_squared_error: 1.8297
# Epoch 53/500
# 614/614 [==============================] - 0s 137us/sample - loss: 5.6035 - y1_output_loss: 1.8645 - y2_output_loss: 3.7443 - y1_output_root_mean_squared_error: 1.3711 - y2_output_root_mean_squared_error: 1.9297 - val_loss: 13.4088 - val_y1_output_loss: 3.1260 - val_y2_output_loss: 9.8602 - val_y1_output_root_mean_squared_error: 1.7893 - val_y2_output_root_mean_squared_error: 3.1949
# Epoch 54/500
# 614/614 [==============================] - 0s 130us/sample - loss: 6.8147 - y1_output_loss: 1.9540 - y2_output_loss: 4.8972 - y1_output_root_mean_squared_error: 1.3982 - y2_output_root_mean_squared_error: 2.2045 - val_loss: 16.8867 - val_y1_output_loss: 2.9879 - val_y2_output_loss: 13.3455 - val_y1_output_root_mean_squared_error: 1.7571 - val_y2_output_root_mean_squared_error: 3.7147
# Epoch 55/500
# 614/614 [==============================] - 0s 138us/sample - loss: 11.8091 - y1_output_loss: 3.6307 - y2_output_loss: 8.0781 - y1_output_root_mean_squared_error: 1.9120 - y2_output_root_mean_squared_error: 2.8554 - val_loss: 4.7369 - val_y1_output_loss: 1.7295 - val_y2_output_loss: 2.8782 - val_y1_output_root_mean_squared_error: 1.3335 - val_y2_output_root_mean_squared_error: 1.7201
# Epoch 56/500
# 614/614 [==============================] - 0s 126us/sample - loss: 5.3854 - y1_output_loss: 1.5905 - y2_output_loss: 3.7490 - y1_output_root_mean_squared_error: 1.2668 - y2_output_root_mean_squared_error: 1.9444 - val_loss: 4.9559 - val_y1_output_loss: 1.8521 - val_y2_output_loss: 2.9547 - val_y1_output_root_mean_squared_error: 1.3823 - val_y2_output_root_mean_squared_error: 1.7451
# Epoch 57/500
# 614/614 [==============================] - 0s 126us/sample - loss: 8.4983 - y1_output_loss: 2.5542 - y2_output_loss: 6.0481 - y1_output_root_mean_squared_error: 1.5934 - y2_output_root_mean_squared_error: 2.4412 - val_loss: 27.6316 - val_y1_output_loss: 11.1888 - val_y2_output_loss: 15.4990 - val_y1_output_root_mean_squared_error: 3.4048 - val_y2_output_root_mean_squared_error: 4.0049
# Epoch 58/500
# 614/614 [==============================] - 0s 132us/sample - loss: 7.4626 - y1_output_loss: 2.1581 - y2_output_loss: 5.2556 - y1_output_root_mean_squared_error: 1.4703 - y2_output_root_mean_squared_error: 2.3023 - val_loss: 7.9653 - val_y1_output_loss: 2.7989 - val_y2_output_loss: 4.8933 - val_y1_output_root_mean_squared_error: 1.7025 - val_y2_output_root_mean_squared_error: 2.2509
# Epoch 59/500
# 614/614 [==============================] - 0s 136us/sample - loss: 5.5999 - y1_output_loss: 1.4149 - y2_output_loss: 4.1780 - y1_output_root_mean_squared_error: 1.1898 - y2_output_root_mean_squared_error: 2.0455 - val_loss: 9.2006 - val_y1_output_loss: 1.6919 - val_y2_output_loss: 7.2039 - val_y1_output_root_mean_squared_error: 1.3176 - val_y2_output_root_mean_squared_error: 2.7321
# Epoch 60/500
# 614/614 [==============================] - 0s 146us/sample - loss: 4.9136 - y1_output_loss: 1.4648 - y2_output_loss: 3.4482 - y1_output_root_mean_squared_error: 1.2063 - y2_output_root_mean_squared_error: 1.8597 - val_loss: 4.8400 - val_y1_output_loss: 1.7221 - val_y2_output_loss: 2.9697 - val_y1_output_root_mean_squared_error: 1.3331 - val_y2_output_root_mean_squared_error: 1.7501
# Epoch 61/500
# 614/614 [==============================] - 0s 127us/sample - loss: 4.5646 - y1_output_loss: 1.4464 - y2_output_loss: 3.0761 - y1_output_root_mean_squared_error: 1.2082 - y2_output_root_mean_squared_error: 1.7620 - val_loss: 5.4723 - val_y1_output_loss: 2.0531 - val_y2_output_loss: 3.2388 - val_y1_output_root_mean_squared_error: 1.4567 - val_y2_output_root_mean_squared_error: 1.8304
# Epoch 62/500
# 614/614 [==============================] - 0s 140us/sample - loss: 7.2330 - y1_output_loss: 2.2100 - y2_output_loss: 4.9667 - y1_output_root_mean_squared_error: 1.4914 - y2_output_root_mean_squared_error: 2.2380 - val_loss: 5.9941 - val_y1_output_loss: 2.4703 - val_y2_output_loss: 3.3280 - val_y1_output_root_mean_squared_error: 1.5992 - val_y2_output_root_mean_squared_error: 1.8538
# Epoch 63/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.5214 - y1_output_loss: 1.3251 - y2_output_loss: 3.1580 - y1_output_root_mean_squared_error: 1.1567 - y2_output_root_mean_squared_error: 1.7842 - val_loss: 10.3310 - val_y1_output_loss: 3.7555 - val_y2_output_loss: 6.2228 - val_y1_output_root_mean_squared_error: 1.9707 - val_y2_output_root_mean_squared_error: 2.5391
# Epoch 64/500
# 614/614 [==============================] - 0s 133us/sample - loss: 5.0629 - y1_output_loss: 1.3365 - y2_output_loss: 3.6985 - y1_output_root_mean_squared_error: 1.1586 - y2_output_root_mean_squared_error: 1.9288 - val_loss: 5.0796 - val_y1_output_loss: 1.4867 - val_y2_output_loss: 3.4287 - val_y1_output_root_mean_squared_error: 1.2398 - val_y2_output_root_mean_squared_error: 1.8822
# Epoch 65/500
# 614/614 [==============================] - 0s 139us/sample - loss: 5.2558 - y1_output_loss: 1.6772 - y2_output_loss: 3.5543 - y1_output_root_mean_squared_error: 1.3011 - y2_output_root_mean_squared_error: 1.8876 - val_loss: 4.4677 - val_y1_output_loss: 1.4132 - val_y2_output_loss: 2.9225 - val_y1_output_root_mean_squared_error: 1.2077 - val_y2_output_root_mean_squared_error: 1.7347
# Epoch 66/500
# 614/614 [==============================] - 0s 131us/sample - loss: 8.4812 - y1_output_loss: 2.4238 - y2_output_loss: 5.9973 - y1_output_root_mean_squared_error: 1.5633 - y2_output_root_mean_squared_error: 2.4571 - val_loss: 4.5365 - val_y1_output_loss: 1.6947 - val_y2_output_loss: 2.6843 - val_y1_output_root_mean_squared_error: 1.3246 - val_y2_output_root_mean_squared_error: 1.6679
# Epoch 67/500
# 614/614 [==============================] - 0s 128us/sample - loss: 4.6210 - y1_output_loss: 1.3003 - y2_output_loss: 3.3073 - y1_output_root_mean_squared_error: 1.1458 - y2_output_root_mean_squared_error: 1.8188 - val_loss: 6.4014 - val_y1_output_loss: 1.3239 - val_y2_output_loss: 4.8858 - val_y1_output_root_mean_squared_error: 1.1664 - val_y2_output_root_mean_squared_error: 2.2452
# Epoch 68/500
# 614/614 [==============================] - 0s 131us/sample - loss: 6.3446 - y1_output_loss: 1.7889 - y2_output_loss: 4.4992 - y1_output_root_mean_squared_error: 1.3430 - y2_output_root_mean_squared_error: 2.1310 - val_loss: 4.7836 - val_y1_output_loss: 1.8081 - val_y2_output_loss: 2.8375 - val_y1_output_root_mean_squared_error: 1.3660 - val_y2_output_root_mean_squared_error: 1.7081
# Epoch 69/500
# 614/614 [==============================] - 0s 135us/sample - loss: 5.7096 - y1_output_loss: 1.5546 - y2_output_loss: 4.1366 - y1_output_root_mean_squared_error: 1.2512 - y2_output_root_mean_squared_error: 2.0357 - val_loss: 8.0520 - val_y1_output_loss: 2.4554 - val_y2_output_loss: 5.3398 - val_y1_output_root_mean_squared_error: 1.5932 - val_y2_output_root_mean_squared_error: 2.3481
# Epoch 70/500
# 614/614 [==============================] - 0s 129us/sample - loss: 4.2021 - y1_output_loss: 1.2418 - y2_output_loss: 2.9612 - y1_output_root_mean_squared_error: 1.1166 - y2_output_root_mean_squared_error: 1.7191 - val_loss: 8.2966 - val_y1_output_loss: 1.6882 - val_y2_output_loss: 6.3293 - val_y1_output_root_mean_squared_error: 1.3209 - val_y2_output_root_mean_squared_error: 2.5597
# Epoch 71/500
# 614/614 [==============================] - 0s 129us/sample - loss: 4.3137 - y1_output_loss: 1.1684 - y2_output_loss: 3.1195 - y1_output_root_mean_squared_error: 1.0792 - y2_output_root_mean_squared_error: 1.7746 - val_loss: 4.6154 - val_y1_output_loss: 0.9996 - val_y2_output_loss: 3.4699 - val_y1_output_root_mean_squared_error: 1.0158 - val_y2_output_root_mean_squared_error: 1.8930
# Epoch 72/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.6908 - y1_output_loss: 1.0157 - y2_output_loss: 2.6631 - y1_output_root_mean_squared_error: 1.0067 - y2_output_root_mean_squared_error: 1.6362 - val_loss: 4.5054 - val_y1_output_loss: 1.7465 - val_y2_output_loss: 2.6143 - val_y1_output_root_mean_squared_error: 1.3440 - val_y2_output_root_mean_squared_error: 1.6429
# Epoch 73/500
# 614/614 [==============================] - 0s 126us/sample - loss: 6.3101 - y1_output_loss: 2.0111 - y2_output_loss: 4.2567 - y1_output_root_mean_squared_error: 1.4192 - y2_output_root_mean_squared_error: 2.0727 - val_loss: 3.6339 - val_y1_output_loss: 1.3386 - val_y2_output_loss: 2.1818 - val_y1_output_root_mean_squared_error: 1.1762 - val_y2_output_root_mean_squared_error: 1.5002
# Epoch 74/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.5994 - y1_output_loss: 0.9015 - y2_output_loss: 2.6670 - y1_output_root_mean_squared_error: 0.9532 - y2_output_root_mean_squared_error: 1.6404 - val_loss: 4.1577 - val_y1_output_loss: 1.2432 - val_y2_output_loss: 2.7886 - val_y1_output_root_mean_squared_error: 1.1333 - val_y2_output_root_mean_squared_error: 1.6951
# Epoch 75/500
# 614/614 [==============================] - 0s 128us/sample - loss: 4.6338 - y1_output_loss: 1.1805 - y2_output_loss: 3.4304 - y1_output_root_mean_squared_error: 1.0867 - y2_output_root_mean_squared_error: 1.8582 - val_loss: 6.0173 - val_y1_output_loss: 1.3186 - val_y2_output_loss: 4.4934 - val_y1_output_root_mean_squared_error: 1.1682 - val_y2_output_root_mean_squared_error: 2.1570
# Epoch 76/500
# 614/614 [==============================] - 0s 127us/sample - loss: 4.1742 - y1_output_loss: 1.0296 - y2_output_loss: 3.1154 - y1_output_root_mean_squared_error: 1.0194 - y2_output_root_mean_squared_error: 1.7706 - val_loss: 4.2943 - val_y1_output_loss: 0.8533 - val_y2_output_loss: 3.3096 - val_y1_output_root_mean_squared_error: 0.9366 - val_y2_output_root_mean_squared_error: 1.8485
# Epoch 77/500
# 614/614 [==============================] - 0s 125us/sample - loss: 4.7824 - y1_output_loss: 1.2326 - y2_output_loss: 3.5406 - y1_output_root_mean_squared_error: 1.1125 - y2_output_root_mean_squared_error: 1.8827 - val_loss: 3.9958 - val_y1_output_loss: 0.9675 - val_y2_output_loss: 2.9102 - val_y1_output_root_mean_squared_error: 0.9978 - val_y2_output_root_mean_squared_error: 1.7321
# Epoch 78/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.9336 - y1_output_loss: 1.4763 - y2_output_loss: 3.4684 - y1_output_root_mean_squared_error: 1.2131 - y2_output_root_mean_squared_error: 1.8606 - val_loss: 3.5690 - val_y1_output_loss: 1.3482 - val_y2_output_loss: 2.1300 - val_y1_output_root_mean_squared_error: 1.1753 - val_y2_output_root_mean_squared_error: 1.4790
# Epoch 79/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.9713 - y1_output_loss: 1.1229 - y2_output_loss: 2.8465 - y1_output_root_mean_squared_error: 1.0625 - y2_output_root_mean_squared_error: 1.6859 - val_loss: 3.2453 - val_y1_output_loss: 1.1394 - val_y2_output_loss: 2.0028 - val_y1_output_root_mean_squared_error: 1.0859 - val_y2_output_root_mean_squared_error: 1.4374
# Epoch 80/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.2136 - y1_output_loss: 0.8300 - y2_output_loss: 2.3741 - y1_output_root_mean_squared_error: 0.9103 - y2_output_root_mean_squared_error: 1.5444 - val_loss: 5.3022 - val_y1_output_loss: 0.9182 - val_y2_output_loss: 4.2078 - val_y1_output_root_mean_squared_error: 0.9733 - val_y2_output_root_mean_squared_error: 2.0868
# Epoch 81/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.5204 - y1_output_loss: 0.9804 - y2_output_loss: 2.5332 - y1_output_root_mean_squared_error: 0.9861 - y2_output_root_mean_squared_error: 1.5962 - val_loss: 4.0806 - val_y1_output_loss: 1.5631 - val_y2_output_loss: 2.3815 - val_y1_output_root_mean_squared_error: 1.2720 - val_y2_output_root_mean_squared_error: 1.5693
# Epoch 82/500
# 614/614 [==============================] - 0s 124us/sample - loss: 3.3452 - y1_output_loss: 0.7659 - y2_output_loss: 2.5724 - y1_output_root_mean_squared_error: 0.8753 - y2_output_root_mean_squared_error: 1.6060 - val_loss: 8.6524 - val_y1_output_loss: 2.4782 - val_y2_output_loss: 5.9847 - val_y1_output_root_mean_squared_error: 1.5877 - val_y2_output_root_mean_squared_error: 2.4762
# Epoch 83/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.6140 - y1_output_loss: 0.9942 - y2_output_loss: 2.6039 - y1_output_root_mean_squared_error: 1.0012 - y2_output_root_mean_squared_error: 1.6161 - val_loss: 4.7711 - val_y1_output_loss: 0.7992 - val_y2_output_loss: 3.8137 - val_y1_output_root_mean_squared_error: 0.9050 - val_y2_output_root_mean_squared_error: 1.9880
# Epoch 84/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.1057 - y1_output_loss: 0.7813 - y2_output_loss: 2.3278 - y1_output_root_mean_squared_error: 0.8871 - y2_output_root_mean_squared_error: 1.5227 - val_loss: 4.6368 - val_y1_output_loss: 0.7234 - val_y2_output_loss: 3.7620 - val_y1_output_root_mean_squared_error: 0.8638 - val_y2_output_root_mean_squared_error: 1.9725
# Epoch 85/500
# 614/614 [==============================] - 0s 150us/sample - loss: 2.9611 - y1_output_loss: 0.7650 - y2_output_loss: 2.1799 - y1_output_root_mean_squared_error: 0.8751 - y2_output_root_mean_squared_error: 1.4816 - val_loss: 3.1608 - val_y1_output_loss: 0.9369 - val_y2_output_loss: 2.1206 - val_y1_output_root_mean_squared_error: 0.9844 - val_y2_output_root_mean_squared_error: 1.4805
# Epoch 86/500
# 614/614 [==============================] - 0s 153us/sample - loss: 2.8460 - y1_output_loss: 0.7357 - y2_output_loss: 2.1543 - y1_output_root_mean_squared_error: 0.8604 - y2_output_root_mean_squared_error: 1.4511 - val_loss: 4.2917 - val_y1_output_loss: 1.3009 - val_y2_output_loss: 2.9059 - val_y1_output_root_mean_squared_error: 1.1541 - val_y2_output_root_mean_squared_error: 1.7204
# Epoch 87/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.1661 - y1_output_loss: 0.8658 - y2_output_loss: 2.2886 - y1_output_root_mean_squared_error: 0.9298 - y2_output_root_mean_squared_error: 1.5171 - val_loss: 3.7021 - val_y1_output_loss: 0.9014 - val_y2_output_loss: 2.6995 - val_y1_output_root_mean_squared_error: 0.9610 - val_y2_output_root_mean_squared_error: 1.6669
# Epoch 88/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.6226 - y1_output_loss: 0.7816 - y2_output_loss: 1.8295 - y1_output_root_mean_squared_error: 0.8860 - y2_output_root_mean_squared_error: 1.3556 - val_loss: 3.5637 - val_y1_output_loss: 1.1902 - val_y2_output_loss: 2.2675 - val_y1_output_root_mean_squared_error: 1.1089 - val_y2_output_root_mean_squared_error: 1.5277
# Epoch 89/500
# 614/614 [==============================] - 0s 128us/sample - loss: 4.4304 - y1_output_loss: 1.1459 - y2_output_loss: 3.2613 - y1_output_root_mean_squared_error: 1.0754 - y2_output_root_mean_squared_error: 1.8094 - val_loss: 5.0996 - val_y1_output_loss: 0.7789 - val_y2_output_loss: 4.1448 - val_y1_output_root_mean_squared_error: 0.8979 - val_y2_output_root_mean_squared_error: 2.0720
# Epoch 90/500
# 614/614 [==============================] - 0s 139us/sample - loss: 3.4512 - y1_output_loss: 0.9505 - y2_output_loss: 2.4737 - y1_output_root_mean_squared_error: 0.9784 - y2_output_root_mean_squared_error: 1.5792 - val_loss: 2.4176 - val_y1_output_loss: 0.7336 - val_y2_output_loss: 1.6057 - val_y1_output_root_mean_squared_error: 0.8711 - val_y2_output_root_mean_squared_error: 1.2879
# Epoch 91/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.7488 - y1_output_loss: 0.6952 - y2_output_loss: 2.0627 - y1_output_root_mean_squared_error: 0.8321 - y2_output_root_mean_squared_error: 1.4340 - val_loss: 4.9085 - val_y1_output_loss: 1.6634 - val_y2_output_loss: 3.0705 - val_y1_output_root_mean_squared_error: 1.3133 - val_y2_output_root_mean_squared_error: 1.7843
# Epoch 92/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.9998 - y1_output_loss: 0.7553 - y2_output_loss: 2.2534 - y1_output_root_mean_squared_error: 0.8662 - y2_output_root_mean_squared_error: 1.4998 - val_loss: 2.8621 - val_y1_output_loss: 0.9742 - val_y2_output_loss: 1.7915 - val_y1_output_root_mean_squared_error: 1.0048 - val_y2_output_root_mean_squared_error: 1.3611
# Epoch 93/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.0439 - y1_output_loss: 1.0806 - y2_output_loss: 3.0306 - y1_output_root_mean_squared_error: 1.0224 - y2_output_root_mean_squared_error: 1.7317 - val_loss: 6.7626 - val_y1_output_loss: 2.0220 - val_y2_output_loss: 4.5599 - val_y1_output_root_mean_squared_error: 1.4393 - val_y2_output_root_mean_squared_error: 2.1659
# Epoch 94/500
# 614/614 [==============================] - 0s 133us/sample - loss: 5.3035 - y1_output_loss: 1.3682 - y2_output_loss: 3.9229 - y1_output_root_mean_squared_error: 1.1690 - y2_output_root_mean_squared_error: 1.9842 - val_loss: 6.1938 - val_y1_output_loss: 1.3275 - val_y2_output_loss: 4.6565 - val_y1_output_root_mean_squared_error: 1.1700 - val_y2_output_root_mean_squared_error: 2.1966
# Epoch 95/500
# 614/614 [==============================] - 0s 129us/sample - loss: 4.1797 - y1_output_loss: 1.0176 - y2_output_loss: 3.1279 - y1_output_root_mean_squared_error: 1.0113 - y2_output_root_mean_squared_error: 1.7768 - val_loss: 2.8690 - val_y1_output_loss: 0.8549 - val_y2_output_loss: 1.9159 - val_y1_output_root_mean_squared_error: 0.9410 - val_y2_output_root_mean_squared_error: 1.4084
# Epoch 96/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.4140 - y1_output_loss: 0.8601 - y2_output_loss: 2.5478 - y1_output_root_mean_squared_error: 0.9229 - y2_output_root_mean_squared_error: 1.6007 - val_loss: 3.2080 - val_y1_output_loss: 0.6305 - val_y2_output_loss: 2.4727 - val_y1_output_root_mean_squared_error: 0.8082 - val_y2_output_root_mean_squared_error: 1.5984
# Epoch 97/500
# 614/614 [==============================] - 0s 137us/sample - loss: 4.6694 - y1_output_loss: 1.2421 - y2_output_loss: 3.4030 - y1_output_root_mean_squared_error: 1.1191 - y2_output_root_mean_squared_error: 1.8485 - val_loss: 3.5523 - val_y1_output_loss: 1.1399 - val_y2_output_loss: 2.2888 - val_y1_output_root_mean_squared_error: 1.0862 - val_y2_output_root_mean_squared_error: 1.5402
# Epoch 98/500
# 614/614 [==============================] - 0s 128us/sample - loss: 4.0698 - y1_output_loss: 0.9673 - y2_output_loss: 3.0823 - y1_output_root_mean_squared_error: 0.9846 - y2_output_root_mean_squared_error: 1.7608 - val_loss: 2.6510 - val_y1_output_loss: 0.8440 - val_y2_output_loss: 1.7270 - val_y1_output_root_mean_squared_error: 0.9326 - val_y2_output_root_mean_squared_error: 1.3347
# Epoch 99/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.9455 - y1_output_loss: 0.7489 - y2_output_loss: 2.1708 - y1_output_root_mean_squared_error: 0.8686 - y2_output_root_mean_squared_error: 1.4802 - val_loss: 3.2578 - val_y1_output_loss: 0.7715 - val_y2_output_loss: 2.3772 - val_y1_output_root_mean_squared_error: 0.8933 - val_y2_output_root_mean_squared_error: 1.5684
# Epoch 100/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.6097 - y1_output_loss: 0.9665 - y2_output_loss: 2.6190 - y1_output_root_mean_squared_error: 0.9839 - y2_output_root_mean_squared_error: 1.6253 - val_loss: 2.5844 - val_y1_output_loss: 0.7626 - val_y2_output_loss: 1.7358 - val_y1_output_root_mean_squared_error: 0.8888 - val_y2_output_root_mean_squared_error: 1.3396
# Epoch 101/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.0765 - y1_output_loss: 0.7964 - y2_output_loss: 2.2941 - y1_output_root_mean_squared_error: 0.8935 - y2_output_root_mean_squared_error: 1.5094 - val_loss: 6.9228 - val_y1_output_loss: 1.6716 - val_y2_output_loss: 5.0112 - val_y1_output_root_mean_squared_error: 1.3161 - val_y2_output_root_mean_squared_error: 2.2783
# Epoch 102/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.1159 - y1_output_loss: 0.7936 - y2_output_loss: 2.3387 - y1_output_root_mean_squared_error: 0.8910 - y2_output_root_mean_squared_error: 1.5238 - val_loss: 6.0211 - val_y1_output_loss: 1.4941 - val_y2_output_loss: 4.3510 - val_y1_output_root_mean_squared_error: 1.2423 - val_y2_output_root_mean_squared_error: 2.1161
# Epoch 103/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.9984 - y1_output_loss: 0.7202 - y2_output_loss: 2.2651 - y1_output_root_mean_squared_error: 0.8469 - y2_output_root_mean_squared_error: 1.5104 - val_loss: 2.7484 - val_y1_output_loss: 0.9620 - val_y2_output_loss: 1.6888 - val_y1_output_root_mean_squared_error: 0.9986 - val_y2_output_root_mean_squared_error: 1.3234
# Epoch 104/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.7081 - y1_output_loss: 0.5552 - y2_output_loss: 2.1686 - y1_output_root_mean_squared_error: 0.7427 - y2_output_root_mean_squared_error: 1.4685 - val_loss: 7.0787 - val_y1_output_loss: 2.1595 - val_y2_output_loss: 4.6725 - val_y1_output_root_mean_squared_error: 1.4973 - val_y2_output_root_mean_squared_error: 2.1992
# Epoch 105/500
# 614/614 [==============================] - 0s 126us/sample - loss: 2.7115 - y1_output_loss: 0.6144 - y2_output_loss: 2.1046 - y1_output_root_mean_squared_error: 0.7814 - y2_output_root_mean_squared_error: 1.4495 - val_loss: 2.5041 - val_y1_output_loss: 0.7028 - val_y2_output_loss: 1.7174 - val_y1_output_root_mean_squared_error: 0.8527 - val_y2_output_root_mean_squared_error: 1.3330
# Epoch 106/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.4580 - y1_output_loss: 0.9368 - y2_output_loss: 2.4942 - y1_output_root_mean_squared_error: 0.9703 - y2_output_root_mean_squared_error: 1.5863 - val_loss: 2.2868 - val_y1_output_loss: 0.6158 - val_y2_output_loss: 1.5898 - val_y1_output_root_mean_squared_error: 0.7993 - val_y2_output_root_mean_squared_error: 1.2837
# Epoch 107/500
# 614/614 [==============================] - 0s 130us/sample - loss: 4.2499 - y1_output_loss: 1.1360 - y2_output_loss: 3.1615 - y1_output_root_mean_squared_error: 1.0684 - y2_output_root_mean_squared_error: 1.7631 - val_loss: 7.1954 - val_y1_output_loss: 1.4799 - val_y2_output_loss: 5.4690 - val_y1_output_root_mean_squared_error: 1.2318 - val_y2_output_root_mean_squared_error: 2.3829
# Epoch 108/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.8265 - y1_output_loss: 0.7732 - y2_output_loss: 2.0648 - y1_output_root_mean_squared_error: 0.8762 - y2_output_root_mean_squared_error: 1.4348 - val_loss: 8.1370 - val_y1_output_loss: 2.4978 - val_y2_output_loss: 5.3496 - val_y1_output_root_mean_squared_error: 1.6106 - val_y2_output_root_mean_squared_error: 2.3543
# Epoch 109/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.5786 - y1_output_loss: 0.9169 - y2_output_loss: 2.6580 - y1_output_root_mean_squared_error: 0.9573 - y2_output_root_mean_squared_error: 1.6316 - val_loss: 3.1124 - val_y1_output_loss: 0.9824 - val_y2_output_loss: 2.0765 - val_y1_output_root_mean_squared_error: 0.9998 - val_y2_output_root_mean_squared_error: 1.4535
# Epoch 110/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.5862 - y1_output_loss: 0.6898 - y2_output_loss: 1.9055 - y1_output_root_mean_squared_error: 0.8294 - y2_output_root_mean_squared_error: 1.3778 - val_loss: 4.8228 - val_y1_output_loss: 0.6303 - val_y2_output_loss: 4.0411 - val_y1_output_root_mean_squared_error: 0.8079 - val_y2_output_root_mean_squared_error: 2.0421
# Epoch 111/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.7962 - y1_output_loss: 0.8998 - y2_output_loss: 2.8727 - y1_output_root_mean_squared_error: 0.9503 - y2_output_root_mean_squared_error: 1.7009 - val_loss: 2.2092 - val_y1_output_loss: 0.4573 - val_y2_output_loss: 1.6799 - val_y1_output_root_mean_squared_error: 0.6883 - val_y2_output_root_mean_squared_error: 1.3174
# Epoch 112/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.4586 - y1_output_loss: 0.5496 - y2_output_loss: 1.8897 - y1_output_root_mean_squared_error: 0.7435 - y2_output_root_mean_squared_error: 1.3805 - val_loss: 3.1389 - val_y1_output_loss: 0.6981 - val_y2_output_loss: 2.3418 - val_y1_output_root_mean_squared_error: 0.8480 - val_y2_output_root_mean_squared_error: 1.5556
# Epoch 113/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.7903 - y1_output_loss: 0.6710 - y2_output_loss: 2.1533 - y1_output_root_mean_squared_error: 0.8182 - y2_output_root_mean_squared_error: 1.4563 - val_loss: 3.0965 - val_y1_output_loss: 0.4735 - val_y2_output_loss: 2.5165 - val_y1_output_root_mean_squared_error: 0.6992 - val_y2_output_root_mean_squared_error: 1.6148
# Epoch 114/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.5856 - y1_output_loss: 0.5699 - y2_output_loss: 2.0835 - y1_output_root_mean_squared_error: 0.7549 - y2_output_root_mean_squared_error: 1.4197 - val_loss: 5.9811 - val_y1_output_loss: 0.8223 - val_y2_output_loss: 4.9980 - val_y1_output_root_mean_squared_error: 0.9232 - val_y2_output_root_mean_squared_error: 2.2647
# Epoch 115/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.6112 - y1_output_loss: 0.6024 - y2_output_loss: 2.0042 - y1_output_root_mean_squared_error: 0.7761 - y2_output_root_mean_squared_error: 1.4174 - val_loss: 2.8033 - val_y1_output_loss: 1.1193 - val_y2_output_loss: 1.5849 - val_y1_output_root_mean_squared_error: 1.0774 - val_y2_output_root_mean_squared_error: 1.2816
# Epoch 116/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.3404 - y1_output_loss: 0.7826 - y2_output_loss: 2.5376 - y1_output_root_mean_squared_error: 0.8850 - y2_output_root_mean_squared_error: 1.5991 - val_loss: 3.0350 - val_y1_output_loss: 0.5826 - val_y2_output_loss: 2.3464 - val_y1_output_root_mean_squared_error: 0.7768 - val_y2_output_root_mean_squared_error: 1.5593
# Epoch 117/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.4295 - y1_output_loss: 0.5207 - y2_output_loss: 1.9104 - y1_output_root_mean_squared_error: 0.7184 - y2_output_root_mean_squared_error: 1.3832 - val_loss: 2.4438 - val_y1_output_loss: 0.8083 - val_y2_output_loss: 1.5706 - val_y1_output_root_mean_squared_error: 0.9133 - val_y2_output_root_mean_squared_error: 1.2688
# Epoch 118/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.1909 - y1_output_loss: 0.4982 - y2_output_loss: 1.6810 - y1_output_root_mean_squared_error: 0.7082 - y2_output_root_mean_squared_error: 1.2997 - val_loss: 2.4257 - val_y1_output_loss: 0.5487 - val_y2_output_loss: 1.7973 - val_y1_output_root_mean_squared_error: 0.7538 - val_y2_output_root_mean_squared_error: 1.3629
# Epoch 119/500
# 614/614 [==============================] - 0s 134us/sample - loss: 1.9152 - y1_output_loss: 0.4241 - y2_output_loss: 1.4987 - y1_output_root_mean_squared_error: 0.6437 - y2_output_root_mean_squared_error: 1.2251 - val_loss: 2.1134 - val_y1_output_loss: 0.6835 - val_y2_output_loss: 1.3575 - val_y1_output_root_mean_squared_error: 0.8416 - val_y2_output_root_mean_squared_error: 1.1853
# Epoch 120/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.2962 - y1_output_loss: 0.8926 - y2_output_loss: 2.3821 - y1_output_root_mean_squared_error: 0.9464 - y2_output_root_mean_squared_error: 1.5494 - val_loss: 3.0922 - val_y1_output_loss: 0.7938 - val_y2_output_loss: 2.1944 - val_y1_output_root_mean_squared_error: 0.9078 - val_y2_output_root_mean_squared_error: 1.5060
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.3805 - y1_output_loss: 0.1144 - y2_output_loss: 0.2648 - y1_output_root_mean_squared_error: 0.3377 - y2_output_root_mean_squared_error: 0.5162 - val_loss: 0.7964 - val_y1_output_loss: 0.2419 - val_y2_output_loss: 0.5319 - val_y1_output_root_mean_squared_error: 0.4976 - val_y2_output_root_mean_squared_error: 0.7408
# Epoch 462/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.4254 - y1_output_loss: 0.1141 - y2_output_loss: 0.3097 - y1_output_root_mean_squared_error: 0.3392 - y2_output_root_mean_squared_error: 0.5571 - val_loss: 0.8845 - val_y1_output_loss: 0.2212 - val_y2_output_loss: 0.6388 - val_y1_output_root_mean_squared_error: 0.4767 - val_y2_output_root_mean_squared_error: 0.8107
# Epoch 463/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3267 - y1_output_loss: 0.1062 - y2_output_loss: 0.2183 - y1_output_root_mean_squared_error: 0.3270 - y2_output_root_mean_squared_error: 0.4688 - val_loss: 0.7125 - val_y1_output_loss: 0.1725 - val_y2_output_loss: 0.5196 - val_y1_output_root_mean_squared_error: 0.4217 - val_y2_output_root_mean_squared_error: 0.7312
# Epoch 464/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3328 - y1_output_loss: 0.1020 - y2_output_loss: 0.2291 - y1_output_root_mean_squared_error: 0.3198 - y2_output_root_mean_squared_error: 0.4801 - val_loss: 0.7246 - val_y1_output_loss: 0.2084 - val_y2_output_loss: 0.4944 - val_y1_output_root_mean_squared_error: 0.4626 - val_y2_output_root_mean_squared_error: 0.7145
# Epoch 465/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.5156 - y1_output_loss: 0.1302 - y2_output_loss: 0.3822 - y1_output_root_mean_squared_error: 0.3626 - y2_output_root_mean_squared_error: 0.6197 - val_loss: 0.6920 - val_y1_output_loss: 0.1980 - val_y2_output_loss: 0.4749 - val_y1_output_root_mean_squared_error: 0.4514 - val_y2_output_root_mean_squared_error: 0.6988
# Epoch 466/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.5015 - y1_output_loss: 0.1216 - y2_output_loss: 0.3761 - y1_output_root_mean_squared_error: 0.3502 - y2_output_root_mean_squared_error: 0.6155 - val_loss: 1.0045 - val_y1_output_loss: 0.3023 - val_y2_output_loss: 0.6762 - val_y1_output_root_mean_squared_error: 0.5541 - val_y2_output_root_mean_squared_error: 0.8352
# Epoch 467/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3711 - y1_output_loss: 0.1207 - y2_output_loss: 0.2493 - y1_output_root_mean_squared_error: 0.3488 - y2_output_root_mean_squared_error: 0.4994 - val_loss: 0.9085 - val_y1_output_loss: 0.2014 - val_y2_output_loss: 0.6803 - val_y1_output_root_mean_squared_error: 0.4532 - val_y2_output_root_mean_squared_error: 0.8385
# Epoch 468/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.4460 - y1_output_loss: 0.1273 - y2_output_loss: 0.3171 - y1_output_root_mean_squared_error: 0.3563 - y2_output_root_mean_squared_error: 0.5648 - val_loss: 1.1354 - val_y1_output_loss: 0.2610 - val_y2_output_loss: 0.8492 - val_y1_output_root_mean_squared_error: 0.5135 - val_y2_output_root_mean_squared_error: 0.9336
# Epoch 469/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4532 - y1_output_loss: 0.1375 - y2_output_loss: 0.3152 - y1_output_root_mean_squared_error: 0.3720 - y2_output_root_mean_squared_error: 0.5611 - val_loss: 1.3060 - val_y1_output_loss: 0.2431 - val_y2_output_loss: 1.0209 - val_y1_output_root_mean_squared_error: 0.4997 - val_y2_output_root_mean_squared_error: 1.0278
# Epoch 470/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4351 - y1_output_loss: 0.1195 - y2_output_loss: 0.3181 - y1_output_root_mean_squared_error: 0.3439 - y2_output_root_mean_squared_error: 0.5628 - val_loss: 0.6923 - val_y1_output_loss: 0.1861 - val_y2_output_loss: 0.4895 - val_y1_output_root_mean_squared_error: 0.4365 - val_y2_output_root_mean_squared_error: 0.7083
# Epoch 471/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.5656 - y1_output_loss: 0.1427 - y2_output_loss: 0.4278 - y1_output_root_mean_squared_error: 0.3793 - y2_output_root_mean_squared_error: 0.6494 - val_loss: 1.9039 - val_y1_output_loss: 0.3997 - val_y2_output_loss: 1.4401 - val_y1_output_root_mean_squared_error: 0.6424 - val_y2_output_root_mean_squared_error: 1.2212
# Epoch 472/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.5203 - y1_output_loss: 0.1446 - y2_output_loss: 0.3757 - y1_output_root_mean_squared_error: 0.3812 - y2_output_root_mean_squared_error: 0.6124 - val_loss: 1.2219 - val_y1_output_loss: 0.2129 - val_y2_output_loss: 0.9763 - val_y1_output_root_mean_squared_error: 0.4674 - val_y2_output_root_mean_squared_error: 1.0017
# Epoch 473/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4132 - y1_output_loss: 0.1268 - y2_output_loss: 0.2877 - y1_output_root_mean_squared_error: 0.3575 - y2_output_root_mean_squared_error: 0.5342 - val_loss: 1.2638 - val_y1_output_loss: 0.2225 - val_y2_output_loss: 1.0022 - val_y1_output_root_mean_squared_error: 0.4793 - val_y2_output_root_mean_squared_error: 1.0169
# Epoch 474/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.4034 - y1_output_loss: 0.1320 - y2_output_loss: 0.2702 - y1_output_root_mean_squared_error: 0.3629 - y2_output_root_mean_squared_error: 0.5213 - val_loss: 0.9339 - val_y1_output_loss: 0.1888 - val_y2_output_loss: 0.7163 - val_y1_output_root_mean_squared_error: 0.4393 - val_y2_output_root_mean_squared_error: 0.8608
# Epoch 475/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4001 - y1_output_loss: 0.1106 - y2_output_loss: 0.2944 - y1_output_root_mean_squared_error: 0.3305 - y2_output_root_mean_squared_error: 0.5393 - val_loss: 0.9904 - val_y1_output_loss: 0.1779 - val_y2_output_loss: 0.7804 - val_y1_output_root_mean_squared_error: 0.4281 - val_y2_output_root_mean_squared_error: 0.8984
# Epoch 476/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.4890 - y1_output_loss: 0.1268 - y2_output_loss: 0.3599 - y1_output_root_mean_squared_error: 0.3575 - y2_output_root_mean_squared_error: 0.6010 - val_loss: 1.0741 - val_y1_output_loss: 0.2475 - val_y2_output_loss: 0.7972 - val_y1_output_root_mean_squared_error: 0.5011 - val_y2_output_root_mean_squared_error: 0.9072
# Epoch 477/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3434 - y1_output_loss: 0.0990 - y2_output_loss: 0.2436 - y1_output_root_mean_squared_error: 0.3147 - y2_output_root_mean_squared_error: 0.4943 - val_loss: 0.6640 - val_y1_output_loss: 0.1885 - val_y2_output_loss: 0.4561 - val_y1_output_root_mean_squared_error: 0.4387 - val_y2_output_root_mean_squared_error: 0.6867
# Epoch 478/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3947 - y1_output_loss: 0.1167 - y2_output_loss: 0.2852 - y1_output_root_mean_squared_error: 0.3425 - y2_output_root_mean_squared_error: 0.5267 - val_loss: 2.6668 - val_y1_output_loss: 0.2409 - val_y2_output_loss: 2.3321 - val_y1_output_root_mean_squared_error: 0.4978 - val_y2_output_root_mean_squared_error: 1.5553
# Epoch 479/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.5396 - y1_output_loss: 0.1378 - y2_output_loss: 0.3972 - y1_output_root_mean_squared_error: 0.3721 - y2_output_root_mean_squared_error: 0.6333 - val_loss: 0.6811 - val_y1_output_loss: 0.1880 - val_y2_output_loss: 0.4779 - val_y1_output_root_mean_squared_error: 0.4392 - val_y2_output_root_mean_squared_error: 0.6987
# Epoch 480/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.3002 - y1_output_loss: 0.0928 - y2_output_loss: 0.2056 - y1_output_root_mean_squared_error: 0.3054 - y2_output_root_mean_squared_error: 0.4549 - val_loss: 0.6713 - val_y1_output_loss: 0.1816 - val_y2_output_loss: 0.4740 - val_y1_output_root_mean_squared_error: 0.4316 - val_y2_output_root_mean_squared_error: 0.6965
# Epoch 481/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.3058 - y1_output_loss: 0.0921 - y2_output_loss: 0.2165 - y1_output_root_mean_squared_error: 0.3027 - y2_output_root_mean_squared_error: 0.4629 - val_loss: 0.9153 - val_y1_output_loss: 0.2016 - val_y2_output_loss: 0.6845 - val_y1_output_root_mean_squared_error: 0.4554 - val_y2_output_root_mean_squared_error: 0.8413
# Epoch 482/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.5017 - y1_output_loss: 0.1336 - y2_output_loss: 0.3637 - y1_output_root_mean_squared_error: 0.3671 - y2_output_root_mean_squared_error: 0.6057 - val_loss: 0.7371 - val_y1_output_loss: 0.1879 - val_y2_output_loss: 0.5271 - val_y1_output_root_mean_squared_error: 0.4392 - val_y2_output_root_mean_squared_error: 0.7377
# Epoch 483/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.4216 - y1_output_loss: 0.1139 - y2_output_loss: 0.3073 - y1_output_root_mean_squared_error: 0.3370 - y2_output_root_mean_squared_error: 0.5551 - val_loss: 1.7767 - val_y1_output_loss: 0.4253 - val_y2_output_loss: 1.3086 - val_y1_output_root_mean_squared_error: 0.6599 - val_y2_output_root_mean_squared_error: 1.1581
# Epoch 484/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3582 - y1_output_loss: 0.1135 - y2_output_loss: 0.2453 - y1_output_root_mean_squared_error: 0.3340 - y2_output_root_mean_squared_error: 0.4966 - val_loss: 0.8688 - val_y1_output_loss: 0.3192 - val_y2_output_loss: 0.5210 - val_y1_output_root_mean_squared_error: 0.5746 - val_y2_output_root_mean_squared_error: 0.7339
# Epoch 485/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.4163 - y1_output_loss: 0.1209 - y2_output_loss: 0.2929 - y1_output_root_mean_squared_error: 0.3492 - y2_output_root_mean_squared_error: 0.5425 - val_loss: 1.0033 - val_y1_output_loss: 0.2938 - val_y2_output_loss: 0.6811 - val_y1_output_root_mean_squared_error: 0.5483 - val_y2_output_root_mean_squared_error: 0.8383
# Epoch 486/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3392 - y1_output_loss: 0.0978 - y2_output_loss: 0.2433 - y1_output_root_mean_squared_error: 0.3135 - y2_output_root_mean_squared_error: 0.4909 - val_loss: 1.1660 - val_y1_output_loss: 0.2063 - val_y2_output_loss: 0.9282 - val_y1_output_root_mean_squared_error: 0.4608 - val_y2_output_root_mean_squared_error: 0.9765
# Epoch 487/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.5184 - y1_output_loss: 0.1295 - y2_output_loss: 0.3847 - y1_output_root_mean_squared_error: 0.3611 - y2_output_root_mean_squared_error: 0.6229 - val_loss: 0.7251 - val_y1_output_loss: 0.1911 - val_y2_output_loss: 0.5144 - val_y1_output_root_mean_squared_error: 0.4420 - val_y2_output_root_mean_squared_error: 0.7279
# Epoch 488/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.6691 - y1_output_loss: 0.1722 - y2_output_loss: 0.4915 - y1_output_root_mean_squared_error: 0.4162 - y2_output_root_mean_squared_error: 0.7042 - val_loss: 0.7252 - val_y1_output_loss: 0.2216 - val_y2_output_loss: 0.4817 - val_y1_output_root_mean_squared_error: 0.4775 - val_y2_output_root_mean_squared_error: 0.7052
# Epoch 489/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.3222 - y1_output_loss: 0.1070 - y2_output_loss: 0.2177 - y1_output_root_mean_squared_error: 0.3264 - y2_output_root_mean_squared_error: 0.4644 - val_loss: 1.1374 - val_y1_output_loss: 0.3039 - val_y2_output_loss: 0.7989 - val_y1_output_root_mean_squared_error: 0.5589 - val_y2_output_root_mean_squared_error: 0.9083
# Epoch 490/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3237 - y1_output_loss: 0.1067 - y2_output_loss: 0.2148 - y1_output_root_mean_squared_error: 0.3274 - y2_output_root_mean_squared_error: 0.4653 - val_loss: 0.7149 - val_y1_output_loss: 0.1850 - val_y2_output_loss: 0.5086 - val_y1_output_root_mean_squared_error: 0.4359 - val_y2_output_root_mean_squared_error: 0.7245
# Epoch 491/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.5650 - y1_output_loss: 0.1693 - y2_output_loss: 0.3967 - y1_output_root_mean_squared_error: 0.4131 - y2_output_root_mean_squared_error: 0.6280 - val_loss: 0.8987 - val_y1_output_loss: 0.1979 - val_y2_output_loss: 0.6724 - val_y1_output_root_mean_squared_error: 0.4514 - val_y2_output_root_mean_squared_error: 0.8337
# Epoch 492/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.4027 - y1_output_loss: 0.1195 - y2_output_loss: 0.2902 - y1_output_root_mean_squared_error: 0.3468 - y2_output_root_mean_squared_error: 0.5314 - val_loss: 2.9656 - val_y1_output_loss: 0.3048 - val_y2_output_loss: 2.5572 - val_y1_output_root_mean_squared_error: 0.5607 - val_y2_output_root_mean_squared_error: 1.6283
# Epoch 493/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4800 - y1_output_loss: 0.1139 - y2_output_loss: 0.3661 - y1_output_root_mean_squared_error: 0.3380 - y2_output_root_mean_squared_error: 0.6048 - val_loss: 1.0508 - val_y1_output_loss: 0.1674 - val_y2_output_loss: 0.8484 - val_y1_output_root_mean_squared_error: 0.4151 - val_y2_output_root_mean_squared_error: 0.9373
# Epoch 494/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.6955 - y1_output_loss: 0.1547 - y2_output_loss: 0.5344 - y1_output_root_mean_squared_error: 0.3950 - y2_output_root_mean_squared_error: 0.7345 - val_loss: 0.8799 - val_y1_output_loss: 0.1750 - val_y2_output_loss: 0.6771 - val_y1_output_root_mean_squared_error: 0.4240 - val_y2_output_root_mean_squared_error: 0.8368
# Epoch 495/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4343 - y1_output_loss: 0.1108 - y2_output_loss: 0.3207 - y1_output_root_mean_squared_error: 0.3337 - y2_output_root_mean_squared_error: 0.5682 - val_loss: 0.7237 - val_y1_output_loss: 0.1731 - val_y2_output_loss: 0.5275 - val_y1_output_root_mean_squared_error: 0.4225 - val_y2_output_root_mean_squared_error: 0.7384
# Epoch 496/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3948 - y1_output_loss: 0.1035 - y2_output_loss: 0.2937 - y1_output_root_mean_squared_error: 0.3223 - y2_output_root_mean_squared_error: 0.5393 - val_loss: 2.0776 - val_y1_output_loss: 0.2588 - val_y2_output_loss: 1.7512 - val_y1_output_root_mean_squared_error: 0.5156 - val_y2_output_root_mean_squared_error: 1.3460
# Epoch 497/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3647 - y1_output_loss: 0.1222 - y2_output_loss: 0.2608 - y1_output_root_mean_squared_error: 0.3389 - y2_output_root_mean_squared_error: 0.4998 - val_loss: 4.7288 - val_y1_output_loss: 1.6540 - val_y2_output_loss: 2.9080 - val_y1_output_root_mean_squared_error: 1.3102 - val_y2_output_root_mean_squared_error: 1.7355
# Epoch 498/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.4682 - y1_output_loss: 0.1444 - y2_output_loss: 0.3200 - y1_output_root_mean_squared_error: 0.3812 - y2_output_root_mean_squared_error: 0.5682 - val_loss: 0.6906 - val_y1_output_loss: 0.2247 - val_y2_output_loss: 0.4449 - val_y1_output_root_mean_squared_error: 0.4814 - val_y2_output_root_mean_squared_error: 0.6774
# Epoch 499/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3088 - y1_output_loss: 0.0942 - y2_output_loss: 0.2130 - y1_output_root_mean_squared_error: 0.3081 - y2_output_root_mean_squared_error: 0.4625 - val_loss: 0.7123 - val_y1_output_loss: 0.1621 - val_y2_output_loss: 0.5292 - val_y1_output_root_mean_squared_error: 0.4075 - val_y2_output_root_mean_squared_error: 0.7391
# Epoch 500/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3769 - y1_output_loss: 0.1183 - y2_output_loss: 0.2569 - y1_output_root_mean_squared_error: 0.3451 - y2_output_root_mean_squared_error: 0.5077 - val_loss: 1.0309 - val_y1_output_loss: 0.1798 - val_y2_output_loss: 0.8185 - val_y1_output_root_mean_squared_error: 0.4294 - val_y2_output_root_mean_squared_error: 0.9201

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 31us/sample - loss: 1.0309 - y1_output_loss: 0.1949 - y2_output_loss: 0.8476 - y1_output_root_mean_squared_error: 0.4294 - y2_output_root_mean_squared_error: 0.9201
# Loss = 1.0309212950917033, Y1_loss = 0.19485369324684143, Y1_mse = 0.42938312888145447, Y2_loss = 0.8475981950759888, Y2_mse = 0.9200823307037354

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 38us/sample - loss: 0.8272 - y1_output_loss: 0.1920 - y2_output_loss: 0.6387 - y1_output_root_mean_squared_error: 0.4355 - y2_output_root_mean_squared_error: 0.7985
# Loss = 0.8272344624841368, Y1_loss = 0.1920401006937027, Y1_mse = 0.4355226457118988, Y2_loss = 0.6386582255363464, Y2_mse = 0.798470139503479

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
